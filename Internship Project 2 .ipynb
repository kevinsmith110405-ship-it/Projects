# %% [markdown]
# # Mileage prediction

# %% [markdown]
# **Objective**: Regression Analysis

# %% [markdown]
# **Data Source** : This data set was taken from the Statlib Library which is maintained at Carnegie Mellon University. This dataset was used in 1983 American Statistical Association Exposition.

# %% [markdown]
# #Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import  data

# %%
Mileage = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv')

# %%
Mileage.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
Mileage.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %% [markdown]
# #Describe Data

# %%
Mileage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
Mileage.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# #remove missing values

# %%
Mileage = Mileage.dropna()

# %%
Mileage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(Mileage, x_vars=['displacement', 'horsepower', 'weight', 'acceleration', 'mpg'], y_vars=['mpg'])

# %%
sns.regplot( x= 'displacement', y='mpg', data=Mileage)
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %% [markdown]
# #Data preprocessing

# %%
Mileage.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
Mileage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# # Define Target Variable (y) and Feature Variables (x)

# %%
Mileage.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
y = Mileage['mpg']
x = Mileage[['displacement', 'horsepower', 'weight','acceleration']]

# %%
y.shape
# Out:
# (392,)

# %%
x.shape
# Out:
# (392, 4)

# %%
x
# Out:
#      displacement  horsepower  weight  acceleration
# 0           307.0       130.0    3504          12.0
# 1           350.0       165.0    3693          11.5
# 2           318.0       150.0    3436          11.0
# 3           304.0       150.0    3433          12.0
# 4           302.0       140.0    3449          10.5
# ..            ...         ...     ...           ...
# 393         140.0        86.0    2790          15.6
# 394          97.0        52.0    2130          24.6
# 395         135.0        84.0    2295          11.6
# 396         120.0        79.0    2625          18.6
# 397         119.0        82.0    2720          19.4
#
# [392 rows x 4 columns]

# %% [markdown]
# #Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X = ss.fit_transform(X)

# %%
X
# Out:
# array([[ 1.07728956,  0.66413273,  0.62054034, -1.285258  ],
#        [ 1.48873169,  1.57459447,  0.84333403, -1.46672362],
#        [ 1.1825422 ,  1.18439658,  0.54038176, -1.64818924],
#        ...,
#        [-0.56847897, -0.53247413, -0.80463202, -1.4304305 ],
#        [-0.7120053 , -0.66254009, -0.41562716,  1.11008813],
#        [-0.72157372, -0.58450051, -0.30364091,  1.40043312]])

# %%
pd.DataFrame(X).describe()
# Out:
#                 0             1             2             3
# count  392.000000  3.920000e+02  3.920000e+02  3.920000e+02
# mean     0.000000  1.812609e-17 -1.812609e-17 -1.812609e-17
# std      1.001278  1.001278e+00  1.001278e+00  1.001278e+00
# min     -1.209563 -1.520975e+00 -1.608575e+00 -2.736983e+00
# 25%     -0.855532 -7.665929e-01 -8.868535e-01 -6.410551e-01
# 50%     -0.415384 -2.853488e-01 -2.052109e-01 -1.499869e-02
# 75%      0.778276  5.600800e-01  7.510927e-01  5.384714e-01
# max      2.493416  3.265452e+00  2.549061e+00  3.360262e+00

# %% [markdown]
# #Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2529,train_size=0.7)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((274, 4), (118, 4), (274,), (118,))

# %% [markdown]
# #Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Model Evaluation

# %%
model.intercept_
# Out:
# 23.485738559737584

# %%
model.coef_
# Out:
# array([-1.05767743, -1.68734727, -4.10787617, -0.11495177])

# %% [markdown]
# **Mileage = 23.48 - 1.05 Displacement - 1.68 Horsepower - 4.10 Weight - 0.11 Acceleration + error**

# %% [markdown]
# #Predict Test Data

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([18.51865637, 15.09305675, 14.30128789, 23.6753321 , 29.7546115 ,
#        23.68796629, 26.61066644, 24.56692437, 15.06260986, 11.94312046,
#        24.08050053, 27.96518468, 31.66130278, 31.01309132, 18.32428976,
#        19.32795009, 28.08847536, 32.1506879 , 31.15859692, 27.15792144,
#        18.82433097, 22.54580176, 26.15598115, 32.36393869, 20.74377679,
#         8.78027518, 22.19699435, 18.20614294, 25.00052718, 15.26421552,
#        23.13441082, 17.10542257,  9.87180062, 30.00790415, 20.41204655,
#        29.11860245, 24.4305187 , 21.72601835, 10.51174626, 13.12426391,
#        21.41938406, 19.96113872,  6.19146626, 17.79025345, 22.5493033 ,
#        29.34765021, 13.4861847 , 25.88852083, 29.40406946, 22.41841964,
#        22.07684766, 16.46575802, 24.06290693, 30.12890046, 10.11318121,
#         9.85011438, 28.07543852, 23.41426617, 20.08501128, 30.68234133,
#        20.92026393, 26.78370281, 22.9078744 , 14.15936872, 24.6439883 ,
# ...

# %% [markdown]
# # Model Accuracy

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.3286968643244106

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.14713035779536743

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 17.898948508488033

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7031250746717692

# %% [markdown]
# #Polynomial Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures( degree =2 , interaction_only=True, include_bias=False)

# %%
X_train2 = poly.fit_transform(X_train)

# %%
X_test2 = poly.fit_transform(X_test)

# %%
model.fit(X_train2,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Model Evaluation

# %%
model.intercept_
# Out:
# 21.27336450063766

# %%
model.coef_
# Out:
# array([-2.76070596, -5.00559628, -1.36884133, -0.81225214,  1.24596571,
#        -0.12475017, -0.90542822,  1.35064048, -0.17337823,  1.41680398])

# %% [markdown]
# #Prediction

# %%
y_pred_poly = model.predict(X_test2)

# %%
y_pred_poly
# Out:
# array([15.44878868, 14.01519536, 13.80583049, 25.95331799, 30.89924906,
#        22.68488043, 24.74986967, 22.70743639, 14.37437345, 13.20490013,
#        27.50040536, 28.43976461, 34.62817954, 33.26541987, 18.4667298 ,
#        17.7545968 , 27.48524651, 34.5949536 , 33.48125052, 26.8014229 ,
#        16.8057769 , 21.05722575, 24.33817201, 34.77761918, 18.98156855,
#        15.20071246, 19.36768258, 16.0502785 , 25.74107867, 15.66552393,
#        21.08509734, 15.16602732, 14.01691976, 31.56705822, 19.0231858 ,
#        30.25473337, 22.19778766, 20.91437064, 12.9555207 , 13.42118647,
#        19.66061238, 17.40641384, 14.90285207, 15.96735977, 21.10552747,
#        30.75019604, 13.161465  , 25.17529995, 27.9098963 , 19.87456409,
#        20.90558547, 14.09427836, 23.12005126, 31.84964053, 12.83943937,
#        13.95266816, 27.68977441, 20.86050123, 17.53324298, 32.71815198,
#        19.6516835 , 25.44223418, 21.64139279, 13.69496796, 21.76730595,
# ...

# %% [markdown]
# #Model Accuracy

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred_poly)
# Out:
# 2.7887147720295973

# %%
mean_absolute_percentage_error(y_test, y_pred_poly)
# Out:
# 0.1207401834293869

# %%
mean_squared_error(y_test, y_pred_poly)
# Out:
# 15.303529070735495

# %%
r2_score(y_test,y_pred_poly)
# Out:
# 0.7461731314563802

# %% [markdown]
# # Explaination

# %% [markdown]
# When we compare the linear regression model with the polynomial regression model, we can see that the polynomial regression model has the accuracy of 87% which is higher compared to the accuracy of the linear regression model of 85%.
# The polynomial regression model also has a higher r2 score which means that the model and the prediction is much closer when we compare it to the linear regression model. Also, the polynomial regression model has lower mean squared error and mean absolute error compared to the linear regression model, which means that the polynomial regression model has better accuracy compared to the linear regression model.
